# %% [markdown]
# # Read hw1.csv file and plot figure for visulization

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('hw1.csv')
df
# Out:
#      report_id hospital_id  transfer_idx  disease  ...  age  sex  weight  height
# 0     R0001190    H0032093             2    False  ...   91    1      40     153
# 1     R0001575    H0082188             6    False  ...   64    1      67     181
# 2     R0002763    H0031789             2    False  ...   61    1      56     151
# 3     R0002510    H0092355             6    False  ...   52    0      47     176
# 4     R0001296    H0088464             3     True  ...   65    0      64     157
# ...        ...         ...           ...      ...  ...  ...  ...     ...     ...
# 3065  R0002152    H0019197             1     True  ...   90    1      51     144
# 3066  R0002901    H0024731             1     True  ...   71    1      50     155
# 3067  R0000675    H0091312             0     True  ...   45    1      52     174
# 3068  R0000638    H0092408             1    False  ...   50    1      40     157
# 3069  R0000231    H0088047             0     True  ...   93    1      85     178
#
# [3070 rows x 10 columns]

# %% [markdown]
# #### Q1: Calculate how many unique **repory_id** and **hospital_id** ?
#
# **HINT: np.unique**

# %%
repory = df['report_id']
res = len(set(repory))
print('總共有%d個unique repory_id'%res)

hospital = df['hospital_id']
res = len(set(hospital))
print('總共有%d個unique hospital_id'%res)
# Out:
# 總共有1945個unique repory_id
# 總共有3023個unique hospital_id

# %% [markdown]
# #### Q2: Create a new column named **BMI**
#
# **HINT**: https://zh.wikipedia.org/wiki/%E8%BA%AB%E9%AB%98%E9%AB%94%E9%87%8D%E6%8C%87%E6%95%B8

# %%
df['BMI'] = df['weight']/((df['height']/100)**2)
df
# Out:
#      report_id hospital_id  transfer_idx  ...  weight  height        BMI
# 0     R0001190    H0032093             2  ...      40     153  17.087445
# 1     R0001575    H0082188             6  ...      67     181  20.451146
# 2     R0002763    H0031789             2  ...      56     151  24.560326
# 3     R0002510    H0092355             6  ...      47     176  15.173037
# 4     R0001296    H0088464             3  ...      64     157  25.964542
# ...        ...         ...           ...  ...     ...     ...        ...
# 3065  R0002152    H0019197             1  ...      51     144  24.594907
# 3066  R0002901    H0024731             1  ...      50     155  20.811655
# 3067  R0000675    H0091312             0  ...      52     174  17.175320
# 3068  R0000638    H0092408             1  ...      40     157  16.227839
# 3069  R0000231    H0088047             0  ...      85     178  26.827421
#
# [3070 rows x 11 columns]

# %% [markdown]
# #### Q3: Use Matplotlib to plot figures for the columns, figure type is up to you (bar, plot, histogram , scatter ... etc)

# %%
import matplotlib.pyplot as plt
x = df['BMI']
y = df['age']

plt.scatter(x,y)
plt.xlabel('BMI',fontsize=20)
plt.ylabel('Age',fontsize=20)
plt.show()
